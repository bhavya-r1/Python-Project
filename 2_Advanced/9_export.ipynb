# %%
df_q1.head().to_clipboard(sep=",")

# %%
df_q1.to_csv('quater1.csv')

# %%
pd.read_csv('quater1.csv', index_col=0)

# %%
df_q1.to_excel('quater1.xlsx')

# %%
pd.read_excel('quater1.xlsx', index_col=0)

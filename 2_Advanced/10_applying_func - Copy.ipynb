# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_final = df[pd.notna(df['salary_year_avg'])].copy()
df_final['salary_year_inflated'] = df['salary_year_avg'] * 1.03

df_final[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
import ast
type(ast.literal_eval(df['job_skills'][5]))
# Out:
# list

# %%
import ast
ast.literal_eval(df['job_skills'][3])
# Out:
# ['python', 'c++', 'java', 'matlab', 'aws', 'tensorflow', 'keras', 'pytorch']

# %%
df_skills_clear = df[pd.notna(df['job_skills'])].copy()

# %%
def clean_list(skill_list):
    return ast.literal_eval(skill_list)
df_skills_clear['job_skills']= df_skills_clear['job_skills'].apply(clean_list)

# %%
df_skills_clear
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
type(df_skills_clear['job_skills'][2])
# Out:
# list

# %%
type(df['job_skills'][100])
# Out:
# str

# %%
df_final = df[pd.notna(df['salary_year_avg'])].copy()
df_final['salary_year_inflated'] = df['salary_year_avg'] * 1.03

df_final[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_data = {
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Software Engineer', 'Product Manager', 'Marketing Director', 'HR Manager'],
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'job_location': ['Mountain View, CA', 'Redmond, WA', 'Cupertino, CA', 'Beaverton, OR', 'Seattle, WA']
}

company_data = {
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'industry': ['Technology', 'Technology', 'Technology', 'Apparel', 'Food & Beverage'],
    'company_size': ['100,000+', '100,000+', '100,000+', '75,000+', '346,000+']
}


df_jobs = pd.DataFrame(job_data)
df_companies = pd.DataFrame(company_data)

# %%
df_jobs
# Out:
#    job_id           job_title company_name       job_location
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA

# %%
df_companies
# Out:
#   company_name         industry company_size
# 0       Google       Technology     100,000+
# 1    Microsoft       Technology     100,000+
# 2        Apple       Technology     100,000+
# 3         Nike          Apparel      75,000+
# 4    Starbucks  Food & Beverage     346,000+

# %%
df_job_merge= df_jobs.merge(df_companies, on='company_name')
df_job_merge
# Out:
#    job_id           job_title company_name       job_location  \
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA
#
#           industry company_size
# 0       Technology     100,000+
# 1       Technology     100,000+
# 2       Technology     100,000+
# 3          Apparel      75,000+
# 4  Food & Beverage     346,000+

# %%
df_job_merge.set_index('job_id', inplace=True)

# %%
df_job_merge
# Out:
#                  job_title company_name       job_location         industry  \
# job_id
# 1           Data Scientist       Google  Mountain View, CA       Technology
# 2        Software Engineer    Microsoft        Redmond, WA       Technology
# 3          Product Manager        Apple      Cupertino, CA       Technology
# 4       Marketing Director         Nike      Beaverton, OR          Apparel
# 5               HR Manager    Starbucks        Seattle, WA  Food & Beverage
#
#        company_size
# job_id
# 1          100,000+
# 2          100,000+
# 3          100,000+
# 4           75,000+
# 5          346,000+

# %%
df_india = df[df['job_country'] == 'India'].copy()
df_india['job_posted_month'] = df_india['job_posted_date'].dt.strftime('%B')
df_india_pivot = df_india.pivot_table(
    index='job_posted_month',
    columns='job_title_short',
    aggfunc='size'
)
df_india_pivot.reset_index(inplace=True)
df_india_pivot['month_no']= pd.to_datetime(df_india_pivot['job_posted_month'], format= '%B').dt.month
df_india_pivot.sort_values('month_no', inplace=True)
df_india_pivot.set_index('job_posted_month', inplace=True)
df_india_pivot.drop(columns='month_no', inplace=True)
df_india_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2132            1444                         70
# February                   1631             932                         42
# March                      1591            1005                         34
# April                      1566             946                         54
# May                        1384             837                         31
# June                       1632            1129                         41
# July                       1528            1123                         54
# August                     1407            1157                         47
# September                  1508             984                         67
# October                    1476             902                         85
# November                   1743            1614                         52
# December                   1464            1206                         94
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           127                   448
# February                           94                   313
# March                              96                   351
# April                              86                   375
# May                                59                   329
# June                               66                   427
# July                               75                   359
# August                            126                   343
# September                          85                   324
# October                            67                   318
# November                          125                   423
# December                           77                   343
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                             269                192
# February                            165                157
# March                               194                180
# April                               194                169
# May                                 134                 98
# June                                238                125
# July                                204                155
# August                              235                148
# September                           195                132
# October                             180                167
# November                            278                139
# December                            200                133

# %%
import random

# Set seed for reproducibility
random.seed(42)

# Define job titles
job_titles = ['Front-End Developer', 'Back-End Developer', 'Full-Stack Developer', 'UI/UX Designer']

# Define months
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Define ranges for random data
ranges = {
    'Front-End Developer': (11000, 15000),
    'Back-End Developer': (8000, 10000),
    'Full-Stack Developer': (5000, 7500),
    'UI/UX Designer': (4000, 5000)
}

# Generate random data
data = {}
for job_title in job_titles:
    data[job_title] = [random.randint(ranges[job_title][0], ranges[job_title][1]) for _ in months]

# Create DataFrame
df_US_software_pivot = pd.DataFrame(data, index=months)
df_US_software_pivot.index.name = "job_posted_month"
df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_final= df_india_pivot.merge(df_US_software_pivot, on = 'job_posted_month')
df_final
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2132            1444                         70
# February                   1631             932                         42
# March                      1591            1005                         34
# April                      1566             946                         54
# May                        1384             837                         31
# June                       1632            1129                         41
# July                       1528            1123                         54
# August                     1407            1157                         47
# September                  1508             984                         67
# October                    1476             902                         85
# November                   1743            1614                         52
# December                   1464            1206                         94
#
#                   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           127                   448
# February                           94                   313
# March                              96                   351
# April                              86                   375
# May                                59                   329
# June                               66                   427
# July                               75                   359
# August                            126                   343
# September                          85                   324
# October                            67                   318
# November                          125                   423
# December                           77                   343
#
#                   Senior Data Scientist  Software Engineer  \
# job_posted_month
# January                             269                192
# February                            165                157
# March                               194                180
# April                               194                169
# May                                 134                 98
# June                                238                125
# July                                204                155
# August                              235                148
# September                           195                132
# October                             180                167
# November                            278                139
# December                            200                133
#
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
top_5 = df_final.sum().sort_values(ascending=False).head().index.to_list()
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
df_final[top_5].plot(kind='line')
plt.title('Monthly job posting for Top data jobs in India')
plt.ylabel ('Job Count')
plt.xlabel ('2023')
plt.ylim(0, 20000)
plt.legend()
plt.show ()

# %%
df_da= df[(df['job_title_short']== 'Data Analyst')].copy()
df_da
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# 12                      Lyon, France
# 18                    Warsaw, Poland
# 31                     Paris, France
# 34                 Erlangen, Germany
# ...                              ...
# 785703                      Anywhere
# 785705                   Oakland, CA
# 785715                         India
# 785717                Erfurt, Jerman
# 785737            Bad Rodach, Jerman
#
#                                                   job_via  \
# 1                                        via BeBee México
# 12                                           via Jobijoba
# 18                                  via Praca Trabajo.org
# 31                                           via LinkedIn
# 34                        via Central Illinois Proud Jobs
# ...                                                   ...
# 785703                                       via Snagajob
# 785705                                       via Snagajob
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...
# 785717                                   melalui LinkedIn
# 785737                          melalui BeBee Deutschland
#
#                job_schedule_type  job_work_from_home  \
# 1                      Full-time               False
# 12      Full-time and Internship               False
# 18                     Full-time               False
# 31      Full-time and Internship               False
# 34                     Full-time               False
# ...                          ...                 ...
# 785703                 Full-time                True
# 785705                 Full-time               False
# 785715           Pekerjaan tetap               False
# 785717           Pekerjaan tetap               False
# 785737           Pekerjaan tetap               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 1                          Mexico 2023-01-14 13:18:07                  False
# 12                         France 2023-12-22 13:24:41                  False
# 18                         Poland 2023-10-16 13:36:54                  False
# 31                         France 2023-10-19 13:59:31                  False
# 34                        Germany 2023-02-23 13:31:28                   True
# ...                           ...                 ...                    ...
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
# 785715                      India 2023-03-13 06:16:28                  False
# 785717                    Germany 2023-03-12 06:18:18                  False
# 785737                    Germany 2023-03-12 06:18:18                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 1                      False         Mexico        None              NaN
# 12                     False         France        None              NaN
# 18                     False         Poland        None              NaN
# 31                     False         France        None              NaN
# 34                     False        Germany        None              NaN
# ...                      ...            ...         ...              ...
# 785703                 False  United States        None              NaN
# 785705                 False  United States        None              NaN
# 785715                 False          India        None              NaN
# 785717                 False        Germany        None              NaN
# 785737                 False        Germany        None              NaN
#
#         salary_hour_avg                                       company_name  \
# 1                   NaN                         Hewlett Packard Enterprise
# 12                  NaN                                              Engie
# 18                  NaN                                              Glovo
# 31                  NaN  GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 34                  NaN                                       DEFACTO GmbH
# ...                 ...                                                ...
# 785703              NaN                        Axelon Services Corporation
# 785705              NaN                                   PG&E Corporation
# 785715              NaN                                               Amul
# 785717              NaN                                      NTT DATA DACH
# 785737              NaN                                   HABA FAMILYGROUP
#
#                                                job_skills  \
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 12      ['sql', 'php', 'excel', 'power bi', 'sap', 'ji...
# 18      ['sql', 'python', 'r', 'redshift', 'pandas', '...
# 31                                                ['sql']
# 34                                                ['sap']
# ...                                                   ...
# 785703                                               None
# 785705                       ['sql', 'python', 'tableau']
# 785715                                               None
# 785717                                   ['aws', 'azure']
# 785737                     ['sas', 'sas', 'sql', 'excel']
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12      {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18      {'analyst_tools': ['excel', 'looker', 'tableau...
# 31                               {'programming': ['sql']}
# 34                             {'analyst_tools': ['sap']}
# ...                                                   ...
# 785703                                               None
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
# 785715                                               None
# 785717                        {'cloud': ['aws', 'azure']}
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [196075 rows x 17 columns]

# %%
df_da['month'] = df_da['job_posted_date'].dt.month
df_da.pivot_table(index='month', aggfunc='count' )['job_title_short'].sort_values
# Out:
# <bound method Series.sort_values of month
# 1     23585
# 2     16558
# 3     16243
# 4     15514
# 5     13423
# 6     16008
# 7     16095
# 8     18628
# 9     14969
# 10    16239
# 11    15230
# 12    13583
# Name: job_title_short, dtype: int64>

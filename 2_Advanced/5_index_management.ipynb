# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head(6)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'

# %%
df
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_india = df[df['job_country']=='India']

# %%
df_india.reset_index(inplace=False)
df_india
# Out:
#        index  job_index       job_title_short  \
# 0          0         16         Data Engineer
# 1          1         19        Data Scientist
# 2          2         29        Data Scientist
# 3          3         38          Data Analyst
# 4          4         42  Senior Data Engineer
# ...      ...        ...                   ...
# 51083  51083     785712         Data Engineer
# 51084  51084     785715          Data Analyst
# 51085  51085     785716     Software Engineer
# 51086  51086     785718      Business Analyst
# 51087  51087     785740     Software Engineer
#
#                                                job_title  \
# 0                                      Big Data Engineer
# 1                                         Data Scientist
# 2                                         Data Scientist
# 3                  Data Quality and Governance Analyst 1
# 4            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                  ...
# ...

# %%
df_india.set_index('job_index', inplace=True)

# %%
df_india
# Out:
#            index       job_title_short  \
# job_index
# 16             0         Data Engineer
# 19             1        Data Scientist
# 29             2        Data Scientist
# 38             3          Data Analyst
# 42             4  Senior Data Engineer
# ...          ...                   ...
# 785712     51083         Data Engineer
# 785715     51084          Data Analyst
# 785716     51085     Software Engineer
# 785718     51086      Business Analyst
# 785740     51087     Software Engineer
#
#                                                    job_title  \
# job_index
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# ...

# %%
df_indian=df_india.pivot_table(values='salary_year_avg', index='job_title_short',aggfunc=['median', 'mean', 'max'])
df_indian
# Out:
#                                    median            mean             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0    82255.125000        142025.0
# Data Analyst                     100500.0    99149.925532        650000.0
# Data Engineer                    147500.0   123312.390533        249000.0
# Data Scientist                   114008.0   118203.690217        204381.0
# Machine Learning Engineer         79200.0   111372.570175        267000.0
# Senior Data Analyst              111175.0   105740.592593        177283.0
# Senior Data Engineer             147500.0   132148.631579        181765.0
# Senior Data Scientist            149653.0   126035.787879        170575.0
# Software Engineer                 79200.0    78420.377778        200000.0

# %%
df_indian.sort_values(by=('median', 'salary_year_avg'), ascending=True)
# Out:
#                                    median            mean             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0    82255.125000        142025.0
# Machine Learning Engineer         79200.0   111372.570175        267000.0
# Software Engineer                 79200.0    78420.377778        200000.0
# Data Analyst                     100500.0    99149.925532        650000.0
# Senior Data Analyst              111175.0   105740.592593        177283.0
# Data Scientist                   114008.0   118203.690217        204381.0
# Data Engineer                    147500.0   123312.390533        249000.0
# Senior Data Engineer             147500.0   132148.631579        181765.0
# Senior Data Scientist            149653.0   126035.787879        170575.0

# %%
df_indian.sort_index()
# Out:
#                                    median            mean             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0    82255.125000        142025.0
# Data Analyst                     100500.0    99149.925532        650000.0
# Data Engineer                    147500.0   123312.390533        249000.0
# Data Scientist                   114008.0   118203.690217        204381.0
# Machine Learning Engineer         79200.0   111372.570175        267000.0
# Senior Data Analyst              111175.0   105740.592593        177283.0
# Senior Data Engineer             147500.0   132148.631579        181765.0
# Senior Data Scientist            149653.0   126035.787879        170575.0
# Software Engineer                 79200.0    78420.377778        200000.0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# ...
